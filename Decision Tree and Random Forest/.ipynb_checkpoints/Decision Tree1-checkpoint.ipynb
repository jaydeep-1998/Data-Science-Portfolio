# %%
# Things to do in decision tree
# 1) use continuous/regression variable with and without binning
# 2) how to select features for decision trees
# 3) try prunning 
# 4) hyper-parameter tuning

# %%
#importing al the needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# reading dataset
df = pd.read_csv('bank.csv')

# %%
# Input variables/feature description:

# -bank client data:
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')

# - related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). 
# Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.

# - other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')

# - social and economic context attributes
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)

# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %%
# few samples from dataset
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
# statistical properties of numerical feature in dataset
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
# dataframe summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %% [markdown]
# # EDA

# %%
# visualising age distribution
sns.boxplot(x='age',data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# summary
# sum outliers are present in age 
# most of people have age between 30 to 50

# %%
# visualising categories in job feature and its distribution

g = sns.catplot(data=df,kind='count',x='job')
g.fig.set_size_inches(12,4)
df['job'].value_counts()
# Out:
# management       2566
# blue-collar      1944
# technician       1823
# admin.           1334
# services          923
# retired           778
# self-employed     405
# student           360
# unemployed        357
# entrepreneur      328
# housemaid         274
# unknown            70
# Name: job, dtype: int64

# %%
# summary
# there are some null value which also represented as unknown 
# most of people belongs to  admin,technician,management,blue-collar

# %%
# replaced all the unknown/missing values with forward fill method

df['job'].replace(to_replace='unknown',method='ffill',inplace=True)

# %%
# new distribution of job feature with respect to categories in it.
g = sns.catplot(data=df,kind='count',x='job')
g.fig.set_size_inches(12,4)
df['job'].value_counts()
# Out:
# management       2579
# blue-collar      1953
# technician       1833
# admin.           1340
# services          927
# retired           787
# self-employed     408
# student           366
# unemployed        363
# entrepreneur      329
# housemaid         277
# Name: job, dtype: int64

# %%
# visualising categories in job feature and comparing distribution of each category with respect to target 

g = sns.catplot(data=df,kind='count',x='job',hue='deposit')
g.fig.set_size_inches(12,4)

# %%
# visualising categories in marital feature and its distribution

g = sns.catplot(data=df,kind='count',x='marital')

# %%
# visualising categories in marital feature and its distribution with respect to target variable

g = sns.catplot(data=df,kind='count',x='marital',hue='deposit')

# %%
# summary
# most of people are married and single

# %%
# visualising categories in education feature and its distribution with respect to target variable

g = sns.catplot(data=df,kind='count',x='education',hue='deposit')
print(df['education'].value_counts())
# Out:
# secondary    5476
# tertiary     3689
# primary      1500
# unknown       497
# Name: education, dtype: int64

# %%
# summary
# there are 497 null values

# %%
# replaced all the unknown/missing values with forward fill method

df['education'].replace(to_replace='unknown',method='ffill',inplace=True)
df['education'].value_counts()
# Out:
# secondary    5711
# tertiary     3867
# primary      1584
# Name: education, dtype: int64

# %%
# visualising default feature 
g = sns.catplot(data=df,kind='count',x='default')
print(df['default'].value_counts())
# Out:
# no     10994
# yes      168
# Name: default, dtype: int64

# %%
# visualising default feature with respect to target 
g = sns.catplot(data=df,kind='count',x='default',hue='deposit')

# %%
# summary 
# there are only 168 people who have defaulted the bank out of almost 11000 people

# %%
# visualising the balance feature distribution
g = sns.boxplot(x='balance',data=df)

# %%
#too many outliers in the datasets

# %%
# plotting distribution plot for balance feature
sns.distplot(df['balance'])
# Out:
# /home/jaydeep/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='balance', ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler
df['balance'] = StandardScaler().fit_transform(df[['balance']].values)
# scaled_features_df = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)
sns.distplot(df['balance'])
# Out:
# /home/jaydeep/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='balance', ylabel='Density'>

# %%
# visualising the housing feature distribution
g = sns.catplot(data=df,kind='count',x='housing')
print(df['housing'].value_counts())
# Out:
# no     5881
# yes    5281
# Name: housing, dtype: int64

# %%
# people having housing loan and people don't have are almost same

# %%
# comparing housing(loan) feature with respect to target variable
g = sns.catplot(data=df,kind='count',x='housing',hue='deposit')

# %%
# visualising loan(personal) variable distribution

g = sns.catplot(data=df,kind='count',x='loan')
print(df['loan'].value_counts())
# Out:
# no     9702
# yes    1460
# Name: loan, dtype: int64

# %%
# most of the people don't have personal loan

# %%
# comparing loan(personal) feature with respect to target variable
g = sns.catplot(data=df,kind='count',x='loan',hue='deposit')

# %%
# visualising the contact feature 
g = sns.catplot(data=df,kind='count',x='contact')
print(df['contact'].value_counts())
# Out:
# cellular     8042
# unknown      2346
# telephone     774
# Name: contact, dtype: int64

# %%
# most of the people are having cell phones

# %%
# exploring effect of contact feature on target varible when categories varies
g = sns.catplot(data=df,kind='count',x='contact',hue='deposit')

# %%
# Filling unknown values using forward fill method 
df['contact'].replace(to_replace='unknown',method='ffill',inplace=True)

# %%
# visulising duration feature when compared to target
sns.catplot(data=df,y='duration',x='deposit',kind='box')

# %%
# statistical summary of duration feature
df['duration'].describe()
# Out:
# count    11162.000000
# mean       371.993818
# std        347.128386
# min          2.000000
# 25%        138.000000
# 50%        255.000000
# 75%        496.000000
# max       3881.000000
# Name: duration, dtype: float64

# %%
# we will drop duration feature as of now
df.drop(labels='duration',axis=1,inplace=True)
df
# Out:
#        age          job  marital  education default   balance housing loan  \
# 0       59       admin.  married  secondary      no  0.252525     yes   no
# 1       56       admin.  married  secondary      no -0.459974      no   no
# 2       41   technician  married  secondary      no -0.080160     yes   no
# 3       55     services  married  secondary      no  0.293762     yes   no
# 4       54       admin.  married   tertiary      no -0.416876      no   no
# ...    ...          ...      ...        ...     ...       ...     ...  ...
# 11157   33  blue-collar   single    primary      no -0.473616     yes   no
# 11158   39     services  married  secondary      no -0.246658      no   no
# 11159   32   technician   single  secondary      no -0.464934      no   no
# 11160   43   technician  married  secondary      no -0.473926      no  yes
# 11161   34   technician  married  secondary      no -0.473926      no   no
#
# ...

# %%
# visualising day feature comparing to target
g = sns.catplot(data=df,kind='count',x='day',hue='deposit')

# %%
# visualising month feature comparing to target
g = sns.catplot(data=df,kind='count',x='month',hue='deposit')

# %%
# campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
df['campaign'].unique()
# Out:
# array([ 1,  2,  3,  4,  6,  5,  8, 11,  9, 10, 15, 12, 14,  7, 24, 13, 17,
#        29, 21, 20, 16, 32, 19, 25, 22, 43, 18, 41, 63, 27, 30, 26, 23, 28,
#        33, 31])

# %%
# comparing campaign feature with respect to target
sns.boxplot(data=df,x='campaign',y='deposit')
# Out:
# <AxesSubplot:xlabel='campaign', ylabel='deposit'>

# %%
# outliers are present 
# most of the values are less than 10

# %%
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
df['pdays'].unique()
# Out:
# array([ -1, 166,  91, 147, 170, 150, 171, 126, 182, 110, 198, 174, 175,
#         27, 128, 100, 177, 167, 122, 183, 195, 133, 178,  34,  10, 163,
#        184, 154,  99,  93,   2, 242, 272,  76, 160,  90, 196, 246, 238,
#        203, 268, 189, 267,  92,   9,  88,  85, 210, 257, 261, 270, 106,
#        199, 112,  41, 294, 231, 239, 302, 135, 307, 222, 138, 323, 141,
#        320, 264, 316, 315, 256, 146, 328,  74, 148, 327, 341, 145, 266,
#        234, 345, 318, 325, 274, 343, 260, 305, 344, 254, 180, 340,  82,
#        181, 278, 153,   4, 349, 334, 176,  87, 269,  86, 169,  83,  79,
#          6, 259,  13, 161, 350,  84,  80, 164,  22, 296,  66, 263, 333,
#         17,  89,  78, 286, 337, 364, 188, 342, 363, 352, 295, 353, 356,
#        288, 367, 366, 359, 347, 370, 284, 300, 306, 361, 287, 301, 355,
#        371, 292, 360, 358, 346, 357, 368, 312, 179, 329, 298, 372, 374,
#        375, 291,  95, 109,  94,  98, 186, 101, 187, 321,  40,  96,  21,
# ...

# %%
# visualising the pdays feature distribution 
sns.boxplot(data=df,x='pdays')
# Out:
# <AxesSubplot:xlabel='pdays'>

# %%
# many outlier

# %%
# comparing the pdays feature with respect to target variable
sns.boxplot(data=df,x='pdays',y='deposit')
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='deposit'>

# %%
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
df['previous'].unique()
# Out:
# array([ 0,  1,  4,  2,  3, 10,  7,  9,  5, 29,  6, 13, 17,  8, 11, 30, 22,
#        58, 21, 14, 26, 12, 19, 55, 23, 15, 20, 27, 16, 41, 40, 28, 18, 37])

# %%
# visualising the previous feature distribution 
sns.boxplot(data=df,x='previous')
# Out:
# <AxesSubplot:xlabel='previous'>

# %%
# summary
# there are some outliers
# most of the values are below 4

# %%
# visualising the poutcome feature
g = sns.catplot(data=df,kind='count',x='poutcome')
print(df['poutcome'].value_counts())
# Out:
# unknown    8326
# failure    1228
# success    1071
# other       537
# Name: poutcome, dtype: int64

# %%
# summary
# most of them are null values

# %%
# dropping poutcome feature due to many null values
df.drop(labels = ['poutcome'],axis=1,inplace=True)

# %%
# y - has the client subscribed a term deposit? (binary: 'yes','no')
# visualising the target variable distribution
g = sns.catplot(data=df,kind='count',x='deposit')
print(df['deposit'].value_counts())
# Out:
# no     5873
# yes    5289
# Name: deposit, dtype: int64

# %%
# summary
# data is balance with respect to target value

# %%
# encoding the cateagorical feature
df['deposit'] = df['deposit'].apply(lambda x : 1 if x == 'yes' else 0)

# %%
# finding relationship between age and deposit if any
sns.relplot(x="age", y="deposit", data=df)

# %%
# finding relationship between balance and deposit if any
sns.relplot(x="balance", y="deposit", data=df)

# %%
# finding relationship between pdays and deposit if any
sns.relplot(x='pdays',y='deposit',data=df)

# %%
# visulisation summary 
sns.pairplot(df)

# %%
# finding correlation between feature of the dataset

f, ax = plt.subplots(figsize=(10,6)) #set (x-axis-height,y-axis-height)
sns.heatmap(df.corr(), annot=True, linewidth=".5", cmap="RdPu", fmt=".2f", ax = ax)
#linewidth --Width of the lines that will divide each cell
#cmap is used to set color combination
#fmt is used to set the how much fraction value need after point
#ax is fitting the axis that we want(here we set axis in first line of code)
plt.title("Correlation Map",fontsize=20)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# encoding job feature 
df['job'] = le.fit_transform(df['job'])
df
# Out:
#        age  job  marital  education default   balance housing loan   contact  \
# 0       59    0  married  secondary      no  0.252525     yes   no   unknown
# 1       56    0  married  secondary      no -0.459974      no   no   unknown
# 2       41    9  married  secondary      no -0.080160     yes   no   unknown
# 3       55    7  married  secondary      no  0.293762     yes   no   unknown
# 4       54    0  married   tertiary      no -0.416876      no   no   unknown
# ...    ...  ...      ...        ...     ...       ...     ...  ...       ...
# 11157   33    1   single    primary      no -0.473616     yes   no  cellular
# 11158   39    7  married  secondary      no -0.246658      no   no  cellular
# 11159   32    9   single  secondary      no -0.464934      no   no  cellular
# 11160   43    9  married  secondary      no -0.473926      no  yes  cellular
# 11161   34    9  married  secondary      no -0.473926      no   no  cellular
#
# ...

# %%
# getting error on using apply function on multiple columns

# df[["Integers", "Float"]] = df[["Integers", "Float"]].apply(multiply_by_2)

# df[['default','housing','loan']] = df[['default','housing','loan']].apply(lambda x : 1 if x == 'yes' else 0)

# %%
#this is working but above code is not working

# creating a DataFrame 
df1 = pd.DataFrame({'String 1' :['Tom', 'Nick', 'Krish', 'Jack'], 
                    'String 2' :['Jane', 'John', 'Doe', 'Mohan']}) 

# displaying the DataFrame 
display(df1) 

# function for prepending 'Geek' 
def prepend_geek(name): 
    return 'Geek ' + name 

# executing the function 
df1[["String 1", "String 2"]] = df1[["String 1", "String 2"]].apply(prepend_geek) 

# displaying the DataFrame 
display(df1)
# Out:
#   String 1 String 2
# 0      Tom     Jane
# 1     Nick     John
# 2    Krish      Doe
# 3     Jack    Mohan
#      String 1    String 2
# 0    Geek Tom   Geek Jane
# 1   Geek Nick   Geek John
# 2  Geek Krish    Geek Doe
# 3   Geek Jack  Geek Mohan

# %%
# encoding the default feature
df['default'] = df['default'].apply(lambda x : 1 if x == 'yes' else 0)

# %%
# encoding the housing feature
df['housing'] = df['housing'].apply(lambda x : 1 if x == 'yes' else 0)

# %%
# encoding the housing feature
df['loan'] = df['loan'].apply(lambda x : 1 if x == 'yes' else 0)

# %%
# encoding the marital feature 
le = LabelEncoder()
df['marital'] = le.fit_transform(df['marital'])
df
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       59    0        1        1.0        0  0.252525        1     0
# 1       56    0        1        1.0        0 -0.459974        0     0
# 2       41    9        1        1.0        0 -0.080160        1     0
# 3       55    7        1        1.0        0  0.293762        1     0
# 4       54    0        1        2.0        0 -0.416876        0     0
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 11157   33    1        2        0.0        0 -0.473616        1     0
# 11158   39    7        1        1.0        0 -0.246658        0     0
# 11159   32    9        2        1.0        0 -0.464934        0     0
# 11160   43    9        1        1.0        0 -0.473926        0     1
# 11161   34    9        1        1.0        0 -0.473926        0     0
#
#        contact  day  month  campaign  pdays  previous  deposit
# 0            2    5      8         1     -1         0        1
# ...

# %%
# encoding the contact feature 
le = LabelEncoder()
df['contact'] = le.fit_transform(df['contact'])
df
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       59    0  married  secondary        0  0.252525        1     0
# 1       56    0  married  secondary        0 -0.459974        0     0
# 2       41    9  married  secondary        0 -0.080160        1     0
# 3       55    7  married  secondary        0  0.293762        1     0
# 4       54    0  married   tertiary        0 -0.416876        0     0
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 11157   33    1   single    primary        0 -0.473616        1     0
# 11158   39    7  married  secondary        0 -0.246658        0     0
# 11159   32    9   single  secondary        0 -0.464934        0     0
# 11160   43    9  married  secondary        0 -0.473926        0     1
# 11161   34    9  married  secondary        0 -0.473926        0     0
#
#        contact  day month  campaign  pdays  previous  deposit
# 0            2    5   may         1     -1         0        1
# ...

# %%
# encoding the month feature 
le = LabelEncoder()
df['month'] = le.fit_transform(df['month'])
df
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       59    0  married  secondary        0  0.252525        1     0
# 1       56    0  married  secondary        0 -0.459974        0     0
# 2       41    9  married  secondary        0 -0.080160        1     0
# 3       55    7  married  secondary        0  0.293762        1     0
# 4       54    0  married   tertiary        0 -0.416876        0     0
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 11157   33    1   single    primary        0 -0.473616        1     0
# 11158   39    7  married  secondary        0 -0.246658        0     0
# 11159   32    9   single  secondary        0 -0.464934        0     0
# 11160   43    9  married  secondary        0 -0.473926        0     1
# 11161   34    9  married  secondary        0 -0.473926        0     0
#
#        contact  day  month  campaign  pdays  previous  deposit
# 0            2    5      8         1     -1         0        1
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()
enc.fit(df[['education']])
# Out:
# OrdinalEncoder()

# %%
enc.categories_
# Out:
# [array(['primary', 'secondary', 'tertiary'], dtype=object)]

# %%
# encoding the education feature 
df[['education']] = enc.transform(df[['education']])
df
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 0       59    0  married        1.0        0  0.252525        1     0
# 1       56    0  married        1.0        0 -0.459974        0     0
# 2       41    9  married        1.0        0 -0.080160        1     0
# 3       55    7  married        1.0        0  0.293762        1     0
# 4       54    0  married        2.0        0 -0.416876        0     0
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 11157   33    1   single        0.0        0 -0.473616        1     0
# 11158   39    7  married        1.0        0 -0.246658        0     0
# 11159   32    9   single        1.0        0 -0.464934        0     0
# 11160   43    9  married        1.0        0 -0.473926        0     1
# 11161   34    9  married        1.0        0 -0.473926        0     0
#
#        contact  day  month  campaign  pdays  previous  deposit
# 0            2    5      8         1     -1         0        1
# ...

# %%
# splitting dataframe into dependable and indepedable variables
x = df.drop(labels = ['deposit'],axis=1)
y = df['deposit']

# %%
from sklearn.model_selection import train_test_split

#splitting the dataset into 2/3rd part
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=101)

# %%
# checking training set
x_train
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 9940    38    7        1        1.0        0 -0.710185        1     1
# 4921    36    7        0        1.0        1 -0.473926        0     1
# 10726   51    6        1        1.0        0 -0.460284        1     1
# 1422    54   10        1        1.0        0 -0.357036        0     0
# 9156    33    1        1        1.0        0 -0.385561        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 599     48    3        1        1.0        0 -0.314869        0     1
# 5695    42    1        1        0.0        0 -0.255650        1     1
# 8006    38    6        1        2.0        0  0.172222        1     0
# 1361    32    0        2        2.0        0  2.274992        0     0
# 1547    46    4        1        0.0        0  0.527231        1     0
#
#        contact  day  month  campaign  pdays  previous
# 9940         0   30      8         2     -1         0
# ...

# %% [markdown]
# # Extra code
#
# **one of the use cases of RandomForestClassier**
#
# which can be used for feature selection

# %%
# one of the feature selection method
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(x_train, y_train)
selected_feat= x_train.columns[(sel.get_support())]

print(len(selected_feat))
print(selected_feat)
# Out:
# 5
# Index(['age', 'job', 'balance', 'day', 'month'], dtype='object')

# %% [markdown]
# # Training the model

# %%
# importing the Decision tree 
from sklearn.tree import DecisionTreeClassifier

# taking the depth 4(to just understand the tree that we plot later in the code
decision_tree = DecisionTreeClassifier(max_depth=4)
decision_tree = decision_tree.fit(x_train,y_train)

# %%
# predicting the result of the test data
y_pred = decision_tree.predict(x_test)

# finding r2 score
decision_tree.score(x_test,y_test)
# Out:
# 0.6881107491856677

# %%
from sklearn.metrics import confusion_matrix

# priting confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[1811,  111],
#        [1038,  724]])

# %%
# finding depth of the tree
decision_tree.get_depth()
# Out:
# 4

# %%
# To draw the tree

from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(decision_tree,filled=True)
# Out:
# [Text(366.1875, 489.24, 'X[12] <= 9.5\ngini = 0.498\nsamples = 7478\nvalue = [3951, 3527]'),
#  Text(174.375, 380.52000000000004, 'X[8] <= 1.5\ngini = 0.483\nsamples = 5573\nvalue = [3301, 2272]'),
#  Text(139.5, 271.8, 'X[6] <= 0.5\ngini = 0.472\nsamples = 5335\nvalue = [3301, 2034]'),
#  Text(69.75, 163.08000000000004, 'X[10] <= 0.5\ngini = 0.499\nsamples = 2853\nvalue = [1490, 1363]'),
#  Text(34.875, 54.360000000000014, 'gini = 0.264\nsamples = 217\nvalue = [34, 183]'),
#  Text(104.625, 54.360000000000014, 'gini = 0.495\nsamples = 2636\nvalue = [1456, 1180]'),
#  Text(209.25, 163.08000000000004, 'X[10] <= 9.5\ngini = 0.395\nsamples = 2482\nvalue = [1811, 671]'),
#  Text(174.375, 54.360000000000014, 'gini = 0.386\nsamples = 2446\nvalue = [1808, 638]'),
#  Text(244.125, 54.360000000000014, 'gini = 0.153\nsamples = 36\nvalue = [3, 33]'),
#  Text(209.25, 271.8, 'gini = 0.0\nsamples = 238\nvalue = [0, 238]'),
# ...

# %%
# Model complexity
depth = np.arange(1, 25)
train_accuracy = []
test_accuracy = []

# Loop over different values of depth
for i, d in enumerate(depth):
    # depth from 1 to 25(exclude)
    dt = DecisionTreeClassifier(max_depth = d)
    # Fit with decision tree
    dt.fit(x_train,y_train)
    #train accuracy
    train_accuracy.append(dt.score(x_train, y_train))
    # test accuracy
    test_accuracy.append(dt.score(x_test, y_test))

# Plot
plt.figure(figsize=[13,8])
plt.plot(depth, test_accuracy, label = 'Testing Accuracy')
plt.plot(depth, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('depth of tree')
plt.ylabel('Accuracy')
plt.xticks(depth)
plt.show()
print("Best accuracy is {} with depth = {}".format(np.max(test_accuracy),1+test_accuracy.index(np.max(test_accuracy))))
# Out:
# Best accuracy is 0.7239413680781759 with depth = 7

# %% [markdown]
# **PRUNNING IN DECISION TREES**
#
# SOURCE https://ranvir.xyz/blog/practical-approach-to-tree-pruning-using-sklearn/
#
# Greater values of ccp_alpha increase the number of nodes pruned.

# %%
# taking decision tree classifier instance
clf = DecisionTreeClassifier()

# finding cost complexity path 
path = clf.cost_complexity_pruning_path(x_train, y_train)

# %%
# checking the datatype of the cost complexity path 
type(path)
# Out:
# sklearn.utils.Bunch

# %% [markdown]
# **Cost complexity pruning provides another option to control the size of a tree.**

# %%
# we will take values of ccp_alphas and impurities from path(cost complexity path)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# plotting the ccp_alphas vs impurities
plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, impurities)
plt.xlabel("effective alpha")
plt.ylabel("total impurity of leaves")
# Out:
# Text(0, 0.5, 'total impurity of leaves')

# %%
clfs = []

# taking different instance of DTC using different values of ccp_alpha ,
# then we fit all the models on train data and keep the instance in one list
for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    clf.fit(x_train, y_train)
    clfs.append(clf)

# %%
# print(clfs[0].get_depth(),clfs[0].tree_.max_depth)
# There are two ways by which we can find depth of the tree

# %% [markdown]
# **In DecisionTreeClassifier, this pruning technique is parameterized by the cost complexity parameter, ccp_alpha.
# Greater values of ccp_alpha increase the number of nodes pruned(decreases the depth of the tree)**

# %%
# finding depth of all the trees that are generated by using different values of ccp_apha
tree_depths = [clf.tree_.max_depth for clf in clfs]

# plotting the ccp_alpha vs trees depth
plt.figure(figsize=(10,  6))
plt.plot(ccp_alphas[:-1], tree_depths[:-1])
plt.xlabel("effective alpha")
plt.ylabel("total depth")
# Out:
# Text(0, 0.5, 'total depth')

# %%
from sklearn.metrics import accuracy_score

# finding accuracy of the different trained model 
test_acc_scores = [accuracy_score(y_test, clf.predict(x_test)) for clf in clfs]
train_acc_scores = [accuracy_score(y_train, clf.predict(x_train)) for clf in clfs]

# plotting test and train accuracy vs ccp_alpha values
plt.figure(figsize=(10,  6))
plt.grid()
plt.plot(ccp_alphas[:-1], test_acc_scores[:-1])
plt.plot(ccp_alphas[:-1], train_acc_scores[:-1])
plt.xlabel("effective alpha")
plt.ylabel("Accuracy scores")
# Out:
# Text(0, 0.5, 'Accuracy scores')

# %%
best_accuracy = np.max(test_acc_scores)
index_of_best_accuracy = test_acc_scores.index(np.max(test_acc_scores))
ccp_alpha_for_best_accuracy = ccp_alphas[index_of_best_accuracy]

print("Best accuracy is {} with ccp_alpha value = {}".format(best_accuracy,ccp_alpha_for_best_accuracy))
# Out:
# Best accuracy is 0.7320846905537459 with ccp_alpha value = 0.0006806254302907742

# %%
# # Pruning from the book

# Other algorithms work by first training the Decision Tree without
# restrictions, then pruning (deleting) unnecessary nodes. A node
# whose children are all leaf nodes is considered unnecessary if the
# purity improvement it provides is not statistically significant. Stan‐
# dard statistical tests, such as the χ 2 test, are used to estimate the
# probability that the improvement is purely the result of chance
# (which is called the null hypothesis). If this probability, called the p-
# value, is higher than a given threshold (typically 5%, controlled by
# a hyperparameter), then the node is considered unnecessary and its
# children are deleted. The pruning continues until all unnecessary
# nodes have been pruned.

# %% [markdown]
# # RandomForestClassifier

# %%
# importing the randomforest instance
from sklearn.ensemble import RandomForestClassifier
RFClassifier = RandomForestClassifier(n_estimators=100, random_state=101)

# %%
RFClassifier.fit(x_train,y_train)
y_pred_rf = RFClassifier.predict(x_test)
# Out:
# RandomForestClassifier(random_state=101)

# %%
from sklearn import metrics
print('Accuracy Score:', metrics.accuracy_score(y_test,y_pred_rf))
# Out:
# Accuracy Score: 0.7318132464712269

# %% [markdown]
# # Hyperparameter Tuning

# %%
dt = DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV

space = dict()
space['max_depth'] = np.arange(1, 35)
space['criterion'] = ['gini','entropy']
space['splitter'] = ['best', 'random'] 
space['ccp_alpha'] = [0.0006806254302907742]
space['random_state'] = [0]

search = GridSearchCV(dt, space)

result = search.fit(x_train, y_train)
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# Best Score: 0.6802784318635264
# Best Hyperparameters: {'ccp_alpha': 0.0006806254302907742, 'criterion': 'entropy', 'max_depth': 8, 'random_state': 0, 'splitter': 'best'}

# %%
dt1 = DecisionTreeClassifier(ccp_alpha = 0.0006806254302907742,max_depth=16,random_state=0)
dt1.fit(x_train,y_train)
dt1.score(x_test,y_test)
# Out:
# 0.7320846905537459

# %%
dt1.get_depth()
# Out:
# 16

# %%
dt2 = DecisionTreeClassifier(ccp_alpha = 0.0006806254302907742,random_state=0)
dt2.fit(x_train,y_train)
dt2.score(x_test,y_test)
# Out:
# 0.7320846905537459

# %%
dt2.get_depth()
# Out:
# 16
